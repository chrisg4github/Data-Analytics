# %% [markdown]
# # Data cleansing notes on removed records:
#
# ## See data_engineering.ipynb for more details.
#
# ### Measurement Records Information
#     19,550 total records before changes
#     1,447 records with blank precipitation (col = "prcp")
#     18,103 records with no known issues after removing 1,447 with blank prcp
#     Percentage of records removed is 0.07%
#     Percentage of records remaining is 93.0%

# %%
## Dependencies
import pandas as pd
import numpy as np
import matplotlib
matplotlib.use('nbagg')
from matplotlib import style
style.use('seaborn')
import matplotlib.pyplot as plt
import seaborn as sns
np.random.seed(sum(map(ord, "aesthetics")))
import datetime as dt
from datetime import datetime, date, time

import sqlalchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine, inspect, func, and_

# %%
# Create an engine for the hawaii.sqlite database
engine = create_engine("sqlite:///hawaii.sqlite", echo=False)

# %%
# Use the Inspector to explore the database
inspector = inspect(engine)
inspector.get_table_names()
# Out:
# ['station', 'weather']

# %%
# Use Inspector to print the column names and types
columns = inspector.get_columns('weather')
for c in columns:
    print(c['name'], c["type"])
# Out:
# id INTEGER
# station TEXT
# date TEXT
# prcp FLOAT
# tobs FLOAT

# %%
# Use Inspector to print the column names and types
columns = inspector.get_columns('station')
for c in columns:
    print(c['name'], c["type"])
# Out:
# id INTEGER
# station TEXT
# name TEXT
# latitude FLOAT
# longitude FLOAT
# elevation FLOAT

# %%
# Reflect hawaii database table station into its ORM class
Base = automap_base()
Base.prepare(engine, reflect=True)
station = Base.classes.station

# %%
# Reflect hawaii database table weather into it's ORM class
Base = automap_base()
Base.prepare(engine, reflect=True)
weather = Base.classes.weather

# %%
# Start a session to query the database
session = Session(engine)

# %%
# Get a number for count(*) by using scalar()
session.query(func.count(station.id)).scalar()
# Out:
# 9

# %%
# Get a number for count(*) by using scalar()
session.query(func.count(weather.id)).scalar()
# Out:
# 18103

# %% [markdown]
# # Queries for One Station Precipitation Analysis

# %%
# Station - USC00519397 WAIKIKI 717.2, HI US
s519397 = session.query(weather.date, weather.prcp).\
 filter(and_(weather.date.between('2015-01-01','2015-12-31'), weather.station == 'USC00519397')).\
 order_by(weather.station, weather.date.asc()).all()
s519397
# Out:
# [('2015-01-01', 0.0),
#  ('2015-01-02', 0.04),
#  ('2015-01-03', 0.86),
#  ('2015-01-04', 0.02),
#  ('2015-01-05', 0.0),
#  ('2015-01-06', 0.02),
#  ('2015-01-07', 0.0),
#  ('2015-01-08', 0.0),
#  ('2015-01-09', 0.0),
#  ('2015-01-10', 0.0),
#  ('2015-01-11', 0.0),
#  ('2015-01-12', 0.0),
#  ('2015-01-13', 0.0),
#  ('2015-01-14', 0.0),
#  ('2015-01-15', 0.0),
#  ('2015-01-16', 0.0),
#  ('2015-01-17', 0.0),
#  ('2015-01-18', 0.0),
#  ('2015-01-19', 0.0),
#  ('2015-01-20', 0.0),
#  ('2015-01-21', 0.0),
#  ('2015-01-22', 0.0),
#  ('2015-01-23', 0.0),
#  ('2015-01-24', 0.2),
#  ('2015-01-25', 0.03),
#  ('2015-01-26', 0.0),
#  ('2015-01-27', 0.0),
#  ('2015-01-28', 0.0),
#  ('2015-01-29', 0.0),
#  ('2015-01-30', 0.0),
#  ('2015-01-31', 0.0),
#  ('2015-02-01', 0.0),
#  ('2015-02-02', 0.0),
#  ('2015-02-03', 0.0),
#  ('2015-02-04', 0.01),
#  ('2015-02-05', 0.19),
#  ('2015-02-06', 0.0),
#  ('2015-02-07', 0.0),
#  ('2015-02-08', 0.0),
#  ('2015-02-09', 0.0),
#  ('2015-02-10', 0.1),
#  ('2015-02-11', 0.0),
#  ('2015-02-12', 0.0),
#  ('2015-02-13', 0.0),
#  ('2015-02-14', 0.08),
#  ('2015-02-15', 0.46),
#  ('2015-02-16', 0.0),
#  ('2015-02-17', 0.0),
#  ('2015-02-18', 0.0),
#  ('2015-02-19', 0.01),
#  ('2015-02-20', 0.01),
#  ('2015-02-21', 0.24),
#  ('2015-02-22', 0.0),
#  ('2015-02-23', 0.0),
#  ('2015-02-24', 0.0),
#  ('2015-02-25', 0.0),
#  ('2015-02-26', 0.0),
#  ('2015-02-27', 0.0),
#  ('2015-02-28', 0.0),
#  ('2015-03-01', 0.0),
#  ('2015-03-02', 0.0),
#  ('2015-03-03', 0.0),
#  ('2015-03-04', 0.0),
#  ('2015-03-05', 0.65),
#  ('2015-03-08', 0.0),
#  ('2015-03-09', 0.0),
#  ('2015-03-10', 0.0),
#  ('2015-03-11', 0.0),
#  ('2015-03-13', 0.0),
#  ('2015-03-14', 0.0),
#  ('2015-03-15', 0.0),
#  ('2015-03-16', 0.0),
#  ('2015-03-17', 0.0),
#  ('2015-03-18', 0.0),
#  ('2015-03-19', 0.0),
#  ('2015-03-20', 0.05),
#  ('2015-03-21', 0.0),
#  ('2015-03-22', 0.0),
#  ('2015-03-23', 0.0),
#  ('2015-03-24', 0.0),
#  ('2015-03-25', 0.0),
#  ('2015-03-26', 0.26),
#  ('2015-03-27', 0.0),
#  ('2015-03-28', 0.0),
#  ('2015-03-29', 0.41),
#  ('2015-03-30', 0.04),
#  ('2015-03-31', 0.0),
#  ('2015-04-01', 0.0),
#  ('2015-04-02', 0.0),
#  ('2015-04-03', 0.0),
#  ('2015-04-04', 0.0),
#  ('2015-04-05', 0.0),
#  ('2015-04-06', 0.0),
#  ('2015-04-07', 0.0),
#  ('2015-04-08', 0.01),
#  ('2015-04-09', 0.0),
#  ('2015-04-10', 0.0),
#  ('2015-04-11', 0.0),
#  ('2015-04-12', 0.0),
#  ('2015-04-13', 0.0),
#  ('2015-04-14', 0.03),
#  ('2015-04-15', 0.01),
#  ('2015-04-16', 0.0),
#  ('2015-04-17', 0.06),
#  ('2015-04-18', 0.0),
#  ('2015-04-19', 0.0),
#  ('2015-04-20', 0.0),
#  ('2015-04-21', 0.0),
#  ('2015-04-22', 0.03),
#  ('2015-04-23', 0.0),
#  ('2015-04-24', 0.07),
#  ('2015-04-25', 0.0),
#  ('2015-04-26', 0.01),
#  ('2015-04-27', 0.06),
#  ('2015-04-28', 0.04),
#  ('2015-04-29', 0.02),
#  ('2015-04-30', 0.0),
#  ('2015-05-01', 0.06),
#  ('2015-05-02', 0.0),
#  ('2015-05-03', 0.0),
#  ('2015-05-04', 0.0),
#  ('2015-05-05', 0.05),
#  ('2015-05-06', 0.03),
#  ('2015-05-07', 0.01),
#  ('2015-05-08', 0.18),
#  ('2015-05-09', 0.05),
#  ('2015-05-10', 0.0),
#  ('2015-05-11', 0.0),
#  ('2015-05-12', 0.01),
#  ('2015-05-13', 0.0),
#  ('2015-05-14', 0.0),
#  ('2015-05-15', 0.13),
#  ('2015-05-16', 0.0),
#  ('2015-05-17', 0.0),
#  ('2015-05-18', 0.0),
#  ('2015-05-19', 0.0),
#  ('2015-05-20', 0.0),
#  ('2015-05-21', 0.0),
#  ('2015-05-22', 0.0),
#  ('2015-05-23', 0.07),
#  ('2015-05-24', 0.0),
#  ('2015-05-25', 0.0),
#  ('2015-05-26', 0.0),
#  ('2015-05-27', 0.0),
#  ('2015-05-28', 0.0),
#  ('2015-05-29', 0.0),
#  ('2015-05-30', 0.0),
#  ('2015-05-31', 0.0),
#  ('2015-06-01', 0.0),
#  ('2015-06-02', 0.0),
#  ('2015-06-03', 0.0),
#  ('2015-06-04', 0.0),
#  ('2015-06-05', 0.0),
#  ('2015-06-06', 0.0),
#  ('2015-06-07', 0.0),
#  ('2015-06-08', 0.0),
#  ('2015-06-09', 0.0),
#  ('2015-06-10', 0.0),
#  ('2015-06-11', 0.0),
#  ('2015-06-12', 0.0),
#  ('2015-06-13', 0.0),
#  ('2015-06-14', 0.0),
#  ('2015-06-15', 0.0),
#  ('2015-06-16', 0.0),
#  ('2015-06-17', 0.03),
#  ('2015-06-18', 0.0),
#  ('2015-06-19', 0.01),
#  ('2015-06-20', 0.04),
#  ('2015-06-21', 0.0),
#  ('2015-06-22', 0.0),
#  ('2015-06-23', 0.03),
#  ('2015-06-24', 0.03),
#  ('2015-06-25', 0.03),
#  ('2015-06-26', 0.0),
#  ('2015-06-27', 0.0),
#  ('2015-06-28', 0.0),
#  ('2015-06-29', 0.0),
#  ('2015-06-30', 0.0),
#  ('2015-07-01', 0.0),
#  ('2015-07-02', 0.0),
#  ('2015-07-03', 0.0),
#  ('2015-07-04', 0.0),
#  ('2015-07-05', 0.0),
#  ('2015-07-06', 0.0),
#  ('2015-07-07', 0.0),
#  ('2015-07-08', 0.03),
#  ('2015-07-09', 0.0),
#  ('2015-07-10', 0.01),
#  ('2015-07-11', 0.02),
#  ('2015-07-12', 0.02),
#  ('2015-07-13', 0.0),
#  ('2015-07-14', 0.01),
#  ('2015-07-15', 0.0),
#  ('2015-07-16', 0.0),
#  ('2015-07-17', 0.0),
#  ('2015-07-18', 0.0),
#  ('2015-07-19', 0.05),
#  ('2015-07-20', 0.0),
#  ('2015-07-21', 0.0),
#  ('2015-07-22', 0.01),
#  ('2015-07-23', 0.0),
#  ('2015-07-24', 0.0),
#  ('2015-07-25', 0.0),
#  ('2015-07-26', 0.0),
#  ('2015-07-27', 0.0),
#  ('2015-07-28', 0.0),
#  ('2015-07-29', 0.0),
#  ('2015-07-30', 0.0),
#  ('2015-07-31', 0.0),
#  ('2015-08-01', 0.02),
#  ('2015-08-02', 0.0),
#  ('2015-08-03', 0.0),
#  ('2015-08-04', 0.0),
#  ('2015-08-05', 0.0),
#  ('2015-08-06', 0.1),
#  ('2015-08-07', 0.14),
#  ('2015-08-08', 0.0),
#  ('2015-08-09', 0.0),
#  ('2015-08-10', 0.01),
#  ('2015-08-11', 0.0),
#  ('2015-08-12', 0.0),
#  ('2015-08-13', 0.0),
#  ('2015-08-14', 0.0),
#  ('2015-08-15', 0.01),
#  ('2015-08-16', 0.0),
#  ('2015-08-17', 0.01),
#  ('2015-08-18', 0.06),
#  ('2015-08-21', 0.0),
#  ('2015-08-22', 0.0),
#  ('2015-08-23', 0.02),
#  ('2015-08-24', 0.42),
#  ('2015-08-25', 0.2),
#  ('2015-08-26', 0.62),
#  ('2015-08-27', 0.62),
#  ('2015-08-28', 0.06),
#  ('2015-08-29', 0.0),
#  ('2015-08-30', 0.0),
#  ('2015-08-31', 0.0),
#  ('2015-09-01', 0.0),
#  ('2015-09-02', 0.0),
#  ('2015-09-03', 0.23),
#  ('2015-09-04', 0.52),
#  ('2015-09-05', 0.08),
#  ('2015-09-06', 0.0),
#  ('2015-09-07', 0.06),
#  ('2015-09-08', 0.01),
#  ('2015-09-09', 0.0),
#  ('2015-09-10', 0.0),
#  ('2015-09-11', 0.77),
#  ('2015-09-12', 0.5),
#  ('2015-09-13', 0.11),
#  ('2015-09-14', 0.77),
#  ('2015-09-15', 0.26),
#  ('2015-09-16', 0.01),
#  ('2015-09-17', 0.0),
#  ('2015-09-18', 0.02),
#  ('2015-09-19', 0.02),
#  ('2015-09-20', 0.0),
#  ('2015-09-21', 0.07),
#  ('2015-09-22', 0.09),
#  ('2015-09-23', 0.01),
#  ('2015-09-24', 0.0),
#  ('2015-09-25', 0.08),
#  ('2015-09-26', 0.03),
#  ('2015-09-27', 0.15),
#  ('2015-09-28', 0.04),
#  ('2015-09-29', 0.11),
#  ('2015-09-30', 0.04),
#  ('2015-10-01', 0.05),
#  ('2015-10-02', 0.03),
#  ('2015-10-03', 0.0),
#  ('2015-10-04', 0.0),
#  ('2015-10-05', 0.0),
#  ('2015-10-06', 0.0),
#  ('2015-10-07', 0.04),
#  ('2015-10-08', 0.0),
#  ('2015-10-09', 0.0),
#  ('2015-10-10', 0.0),
#  ('2015-10-11', 0.0),
#  ('2015-10-12', 0.03),
#  ('2015-10-13', 0.04),
#  ('2015-10-14', 0.01),
#  ('2015-10-15', 0.01),
#  ('2015-10-16', 0.0),
#  ('2015-10-17', 0.0),
#  ('2015-10-18', 0.04),
#  ('2015-10-19', 0.0),
#  ('2015-10-20', 0.01),
#  ('2015-10-21', 0.06),
#  ('2015-10-22', 0.01),
#  ('2015-10-23', 0.0),
#  ('2015-10-24', 0.0),
#  ('2015-10-25', 0.0),
#  ('2015-10-26', 0.0),
#  ('2015-10-27', 0.11),
#  ('2015-10-28', 0.01),
#  ('2015-10-29', 0.0),
#  ('2015-10-30', 0.0),
#  ('2015-10-31', 0.0),
#  ('2015-11-01', 0.19),
#  ('2015-11-02', 0.01),
#  ('2015-11-03', 0.0),
#  ('2015-11-04', 0.02),
#  ('2015-11-05', 0.03),
#  ('2015-11-06', 0.01),
#  ('2015-11-07', 0.1),
#  ('2015-11-08', 0.02),
#  ('2015-11-09', 0.11),
#  ('2015-11-10', 0.0),
#  ('2015-11-11', 0.0),
#  ('2015-11-12', 0.01),
#  ('2015-11-13', 0.0),
#  ('2015-11-14', 0.17),
#  ('2015-11-15', 0.02),
#  ('2015-11-16', 0.0),
#  ('2015-11-17', 0.0),
#  ('2015-11-18', 0.02),
#  ('2015-11-19', 0.0),
#  ('2015-11-20', 1.57),
#  ('2015-11-21', 0.85),
#  ('2015-11-22', 0.33),
#  ('2015-11-23', 0.62),
#  ('2015-11-24', 0.75),
#  ('2015-11-25', 0.01),
#  ('2015-11-26', 0.36),
#  ('2015-11-27', 0.11),
#  ('2015-11-28', 0.02),
#  ('2015-11-29', 0.03),
#  ('2015-11-30', 0.01),
#  ('2015-12-01', 0.0),
#  ('2015-12-02', 0.0),
#  ('2015-12-03', 0.06),
#  ('2015-12-04', 0.02),
#  ('2015-12-05', 0.0),
#  ('2015-12-06', 0.0),
#  ('2015-12-07', 0.0),
#  ('2015-12-08', 0.0),
#  ('2015-12-09', 0.0),
#  ('2015-12-10', 0.06),
#  ('2015-12-11', 0.0),
#  ('2015-12-12', 0.39),
#  ('2015-12-13', 0.0),
#  ('2015-12-14', 0.0),
#  ('2015-12-15', 0.08),
#  ('2015-12-16', 0.0),
#  ('2015-12-17', 0.02),
#  ('2015-12-18', 0.08),
#  ('2015-12-19', 0.13),
#  ('2015-12-20', 0.03),
#  ('2015-12-21', 0.01),
#  ('2015-12-22', 0.0),
#  ('2015-12-23', 0.0),
#  ('2015-12-24', 0.0),
#  ('2015-12-25', 0.0),
#  ('2015-12-26', 0.02),
#  ('2015-12-27', 0.43),
#  ('2015-12-28', 0.01),
#  ('2015-12-29', 0.0),
#  ('2015-12-30', 0.0),
#  ('2015-12-31', 0.0)]

# %%
# put data into a data frame for charting
s519397_df = pd.DataFrame(s519397) 
print(len(s519397_df.index))
s519397_df.info()
# Out:
# 360
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 360 entries, 0 to 359
# Data columns (total 2 columns):
# date    360 non-null object
# prcp    360 non-null float64
# dtypes: float64(1), object(1)
# memory usage: 5.7+ KB

# %%
# Convert the string to a datetime object
s519397_df["date"] = pd.to_datetime(s519397_df["date"], format='%Y-%m-%d')
s519397_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 360 entries, 0 to 359
# Data columns (total 2 columns):
# date    360 non-null datetime64[ns]
# prcp    360 non-null float64
# dtypes: datetime64[ns](1), float64(1)
# memory usage: 5.7 KB

# %%
# Set the index to the date column for pandas df.plot()
s519397_df = s519397_df.set_index('date')
print(len(s519397_df.index))
s519397_df.info()
s519397_df.head(5)
# Out:
# 360
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 360 entries, 2015-01-01 to 2015-12-31
# Data columns (total 1 columns):
# prcp    360 non-null float64
# dtypes: float64(1)
# memory usage: 5.6 KB
#             prcp
# date
# 2015-01-01  0.00
# 2015-01-02  0.04
# 2015-01-03  0.86
# 2015-01-04  0.02
# 2015-01-05  0.00

# %%
# Summary Statistics for Station - USC00519397 WAIKIKI 717.2, HI US
s519397_df["prcp"].max()
# Out:
# 1.5700000000000001

# %%
# Summary Statistics for Station - USC00519397 WAIKIKI 717.2, HI US
s519397_df["prcp"].min()
# Out:
# 0.0

# %%
# Summary Statistics for Station - USC00519397 WAIKIKI 717.2, HI US
s519397_df["prcp"].mean()
# Out:
# 0.05099999999999995

# %%
# Summary Statistics for Station - USC00519397 WAIKIKI 717.2, HI US
s519397_df["prcp"].sum()
# Out:
# 18.35999999999998

# %%
# Summary Statistics for Station - USC00519397 WAIKIKI 717.2, HI US
s519397_df["prcp"].describe()
# Out:
# count    360.000000
# mean       0.051000
# std        0.155938
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        0.020000
# max        1.570000
# Name: prcp, dtype: float64

# %%
# Pandas DataFrame.plot(kind='bar')

ax = s519397_df.plot(kind='bar',color='magenta', width=1.5, 
                     title="Station - USC00519397 WAIKIKI 717.2, HI US")
ax.set_xlabel("Jan - Dec 2015")
ax.set_ylabel("Precipitation")

n = 25

xticks = ax.xaxis.get_ticklocs()
xticklabels = [l.get_text().replace("00:00:00","") for l in ax.xaxis.get_ticklabels()]
ax.set_xticks(xticks[::n])
ax.set_xticklabels(xticklabels[::n], rotation=45)

plt.tight_layout()
plt.savefig("Station-USC00519397_prcp_jan-dec-2015.png")
plt.show()
# Out:
# <div id='7856dcc4-9fe7-4440-a619-ac03ec7cabf8'></div>

# %% [markdown]
# # Queries for All Stations Mean Precipitation Chart

# %%
station_mean = session.query(weather.date, func.avg(weather.prcp)).\
    filter(weather.date.between('2015-01-01','2015-12-31')).\
    group_by(weather.date).all()
station_mean
# Out:
# [('2015-01-01', 0.0016666666666666668),
#  ('2015-01-02', 0.01),
#  ('2015-01-03', 1.0542857142857145),
#  ('2015-01-04', 0.025714285714285714),
#  ('2015-01-05', 0.0),
#  ('2015-01-06', 0.035),
#  ('2015-01-07', 0.0),
#  ('2015-01-08', 0.0),
#  ('2015-01-09', 0.0),
#  ('2015-01-10', 0.018),
#  ('2015-01-11', 0.0),
#  ('2015-01-12', 0.005714285714285714),
#  ('2015-01-13', 0.0014285714285714286),
#  ('2015-01-14', 0.0),
#  ('2015-01-15', 0.0),
#  ('2015-01-16', 0.0071428571428571435),
#  ('2015-01-17', 0.0071428571428571435),
#  ('2015-01-18', 0.0),
#  ('2015-01-19', 0.0),
#  ('2015-01-20', 0.0014285714285714286),
#  ('2015-01-21', 0.0),
#  ('2015-01-22', 0.0),
#  ('2015-01-23', 0.0),
#  ('2015-01-24', 0.2214285714285714),
#  ('2015-01-25', 0.365),
#  ('2015-01-26', 0.33),
#  ('2015-01-27', 0.002),
#  ('2015-01-28', 0.05),
#  ('2015-01-29', 0.002),
#  ('2015-01-30', 0.028571428571428574),
#  ('2015-01-31', 0.0),
#  ('2015-02-01', 0.012),
#  ('2015-02-02', 0.0),
#  ('2015-02-03', 0.015714285714285715),
#  ('2015-02-04', 0.4166666666666667),
#  ('2015-02-05', 0.04833333333333333),
#  ('2015-02-06', 0.0),
#  ('2015-02-07', 0.0),
#  ('2015-02-08', 0.0),
#  ('2015-02-09', 0.0),
#  ('2015-02-10', 0.11285714285714286),
#  ('2015-02-11', 0.0),
#  ('2015-02-12', 0.0),
#  ('2015-02-13', 0.0),
#  ('2015-12-11', 0.06166666666666667),
#  ('2015-12-12', 0.35166666666666674),
#  ('2015-12-13', 0.006666666666666667),
#  ('2015-12-14', 0.18),
#  ('2015-12-15', 0.19),
#  ('2015-12-16', 0.03833333333333334),
#  ('2015-12-17', 0.1433333333333333),
#  ('2015-12-18', 0.20428571428571432),
#  ('2015-12-19', 0.3716666666666666),
#  ('2015-12-20', 0.15000000000000002),
#  ('2015-12-21', 0.06333333333333334),
#  ('2015-12-22', 0.045000000000000005),
#  ('2015-12-23', 0.3116666666666667),
#  ('2015-12-24', 0.092),
#  ('2015-12-25', 0.48199999999999993),
#  ('2015-12-26', 0.27799999999999997),
#  ('2015-12-27', 0.834),
#  ('2015-12-28', 0.134),
#  ('2015-12-29', 0.05800000000000001),
#  ('2015-12-30', 0.14),
#  ('2015-12-31', 0.0625)]

# %%
# put data into a data frame for charting
# AssertionError: 1 columns passed, passed data had 2 columns
s_mean_df = pd.DataFrame(station_mean, columns=["date", "avg_prcp"]) 
print(len(s_mean_df.index))
s_mean_df.info()
s_mean_df.head(5)
# Out:
# 365
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 365 entries, 0 to 364
# Data columns (total 2 columns):
# date        365 non-null object
# avg_prcp    365 non-null float64
# dtypes: float64(1), object(1)
# memory usage: 5.8+ KB
#          date  avg_prcp
# 0  2015-01-01  0.001667
# 1  2015-01-02  0.010000
# 2  2015-01-03  1.054286
# 3  2015-01-04  0.025714
# 4  2015-01-05  0.000000

# %%
# Convert the string to a datetime object
s_mean_df["date"] = pd.to_datetime(s_mean_df["date"], format='%Y-%m-%d')
s_mean_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 365 entries, 0 to 364
# Data columns (total 2 columns):
# date        365 non-null datetime64[ns]
# avg_prcp    365 non-null float64
# dtypes: datetime64[ns](1), float64(1)
# memory usage: 5.8 KB

# %%
# Set the index to the date column for pandas df.plot()
s_mean_df = s_mean_df.set_index('date')
print(len(s_mean_df.index))
s_mean_df.info()
s_mean_df.head(5)
# Out:
# 365
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 365 entries, 2015-01-01 to 2015-12-31
# Data columns (total 1 columns):
# avg_prcp    365 non-null float64
# dtypes: float64(1)
# memory usage: 5.7 KB
#             avg_prcp
# date
# 2015-01-01  0.001667
# 2015-01-02  0.010000
# 2015-01-03  1.054286
# 2015-01-04  0.025714
# 2015-01-05  0.000000

# %%
# Summary Statistics Average of all Stations HI, US
s_mean_df["avg_prcp"].describe()
# Out:
# count    365.000000
# mean       0.198483
# std        0.326275
# min        0.000000
# 25%        0.014000
# 50%        0.080000
# 75%        0.235714
# max        2.701667
# Name: avg_prcp, dtype: float64

# %%
# Pandas DataFrame.plot(kind='bar')

ax = s_mean_df.plot(kind='bar',color='magenta', width=1.5, 
                    title="All Stations - Average Precipitation, HI US")
ax.set_xlabel("Jan - Dec 2015")
ax.set_ylabel("Precipitation")

n = 25

xticks = ax.xaxis.get_ticklocs()
xticklabels = [l.get_text().replace("00:00:00","") for l in ax.xaxis.get_ticklabels()]
ax.set_xticks(xticks[::n])
ax.set_xticklabels(xticklabels[::n], rotation=45)

plt.tight_layout()
plt.savefig("all_stations_avg_prcp_jan-dec-2015.png")
plt.show()
# Out:
# <div id='5b33e251-90d0-4bf5-b31d-c8cc0f58cfb9'></div>
